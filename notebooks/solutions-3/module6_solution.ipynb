# %% [markdown]
# # Module 6 Practice
#
# For this practice, you are going to pull data from two data sets.
# Merge them, the compare measurements across the data sets using visual variables within Bubble Charts.

# %% [markdown]
# ## Datasets
#
#
# ### state
#
# The **states** data is built into R environments, as are various other data sets (e.g., Iris data).
# The `data()` function loads one of these well known, learning data sets.
#
# All the data sets are described here:
#   *  https://indigo.sgn.missouri.edu/static/mirror_sites/r.org/R-manual/R-devel/library/datasets/html/00Index.html
#
#
# **state.x77**
# ```
#     matrix with 50 rows and 8 columns giving the following statistics in the respective columns.
#
#     Population:
#
#         population estimate as of July 1, 1975
#     Income:
#
#         per capita income (1974)
#     Illiteracy:
#
#         illiteracy (1970, percent of population)
#     Life Exp:
#
#         life expectancy in years (1969–71)
#     Murder:
#
#         murder and non-negligent manslaughter rate per 100,000 population (1976)
#     HS Grad:
#
#         percent high-school graduates (1970)
#     Frost:
#
#         mean number of days with minimum temperature below freezing (1931–1960) in capital or large city
#     Area:
#
#         land area in square miles
# ```
#
# ### crime
# Additionally, we will use our crime data set from the Bubble Chart lab.
# ```
# ../../../datasets/crime.csv
# ```
#
# Lets load these datasets:

# %%
library(datasets)
data(state)
state <-data.frame(state.x77)
state$names<-rownames(state)
head(state)
str(state)
# Out:
#            Population Income Illiteracy Life.Exp Murder HS.Grad Frost Area
# Alabama     3615      3624   2.1        69.05    15.1   41.3     20    50708
# Alaska       365      6315   1.5        69.31    11.3   66.7    152   566432
# Arizona     2212      4530   1.8        70.55     7.8   58.1     15   113417
# Arkansas    2110      3378   1.9        70.66    10.1   39.9     65    51945
# California 21198      5114   1.1        71.71    10.3   62.6     20   156361
# Colorado    2541      4884   0.7        72.06     6.8   63.9    166   103766
#            names
# Alabama    Alabama
# Alaska     Alaska
# Arizona    Arizona
# Arkansas   Arkansas
# California California
# Colorado   Colorado
# 'data.frame':	50 obs. of  9 variables:
#  $ Population: num  3615 365 2212 2110 21198 ...
#  $ Income    : num  3624 6315 4530 3378 5114 ...
#  $ Illiteracy: num  2.1 1.5 1.8 1.9 1.1 0.7 1.1 0.9 1.3 2 ...
#  $ Life.Exp  : num  69 69.3 70.5 70.7 71.7 ...
#  $ Murder    : num  15.1 11.3 7.8 10.1 10.3 6.8 3.1 6.2 10.7 13.9 ...
#  $ HS.Grad   : num  41.3 66.7 58.1 39.9 62.6 63.9 56 54.6 52.6 40.6 ...
#  $ Frost     : num  20 152 15 65 20 166 139 103 11 60 ...
#  $ Area      : num  50708 566432 113417 51945 156361 ...
#  $ names     : chr  "Alabama" "Alaska" "Arizona" "Arkansas" ...

# %%
summary(state)
# Out:
#    Population        Income       Illiteracy       Life.Exp
#  Min.   :  365   Min.   :3098   Min.   :0.500   Min.   :67.96
#  1st Qu.: 1080   1st Qu.:3993   1st Qu.:0.625   1st Qu.:70.12
#  Median : 2838   Median :4519   Median :0.950   Median :70.67
#  Mean   : 4246   Mean   :4436   Mean   :1.170   Mean   :70.88
#  3rd Qu.: 4968   3rd Qu.:4814   3rd Qu.:1.575   3rd Qu.:71.89
#  Max.   :21198   Max.   :6315   Max.   :2.800   Max.   :73.60
#      Murder          HS.Grad          Frost             Area
#  Min.   : 1.400   Min.   :37.80   Min.   :  0.00   Min.   :  1049
#  1st Qu.: 4.350   1st Qu.:48.05   1st Qu.: 66.25   1st Qu.: 36985
#  Median : 6.850   Median :53.25   Median :114.50   Median : 54277
#  Mean   : 7.378   Mean   :53.11   Mean   :104.46   Mean   : 70736
#  3rd Qu.:10.675   3rd Qu.:59.15   3rd Qu.:139.75   3rd Qu.: 81162
#  Max.   :15.100   Max.   :67.30   Max.   :188.00   Max.   :566432
#     names
#  Length:50
#  Class :character
#  Mode  :character

# %%
crime = read.csv("../../../datasets/crime.csv")
# Rename the column state to names
colnames(crime)[which(names(crime) == "state")] <- "names"
head(crime)
crime$names = trimws(crime$names) # these names actually have whitespace, extra spaces.
str(crime)
# Out:
#   names       murder Forcible_rate Robbery aggravated_assult burglary
# 1 Alabama     8.2    34.3          141.4   247.8              953.8
# 2 Alaska      4.8    81.1           80.9   465.1              622.5
# 3 Arizona     7.5    33.8          144.4   327.4              948.4
# 4 Arkansas    6.7    42.9           91.1   386.8             1084.6
# 5 California  6.9    26.0          176.1   317.3              693.3
# 6 Colorado    3.7    43.4           84.6   264.7              744.8
#   larceny_theft motor_vehicle_theft population
# 1 2650.0        288.3                4627851
# 2 2599.1        391.0                 686293
# 3 2965.2        924.4                6500180
# 4 2711.2        262.1                2855390
# 5 1916.5        712.8               36756666
# 6 2735.2        559.5                4861515
# 'data.frame':	50 obs. of  9 variables:
#  $ names              : chr  "Alabama" "Alaska" "Arizona" "Arkansas" ...
#  $ murder             : num  8.2 4.8 7.5 6.7 6.9 3.7 2.9 4.4 5 6.2 ...
#  $ Forcible_rate      : num  34.3 81.1 33.8 42.9 26 43.4 20 44.7 37.1 23.6 ...
#  $ Robbery            : num  141.4 80.9 144.4 91.1 176.1 ...
#  $ aggravated_assult  : num  248 465 327 387 317 ...
#  $ burglary           : num  954 622 948 1085 693 ...
#  $ larceny_theft      : num  2650 2599 2965 2711 1916 ...
#  $ motor_vehicle_theft: num  288 391 924 262 713 ...
#  $ population         : int  4627851 686293 6500180 2855390 36756666 4861515 3501252 873092 18328340 9685744 ...

# %%
library(dplyr)
# Join the tables using the names column
fusion <- (crime %>% inner_join(state, by="names"))
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
summary(fusion)
# Out:
#     names               murder      Forcible_rate      Robbery
#  Length:50          Min.   :1.100   Min.   :13.90   Min.   :  7.4
#  Class :character   1st Qu.:2.550   1st Qu.:26.12   1st Qu.: 66.0
#  Mode  :character   Median :4.700   Median :33.30   Median : 95.4
#                     Mean   :4.714   Mean   :33.80   Mean   :102.8
#                     3rd Qu.:6.575   3rd Qu.:40.25   3rd Qu.:150.1
#                     Max.   :9.900   Max.   :81.10   Max.   :256.7
#  aggravated_assult    burglary      larceny_theft  motor_vehicle_theft
#  Min.   : 61.7     Min.   : 311.9   Min.   :1344   Min.   : 102.0
#  1st Qu.:150.8     1st Qu.: 492.4   1st Qu.:1854   1st Qu.: 215.0
#  Median :231.8     Median : 665.1   Median :2353   Median : 317.8
#  Mean   :260.4     Mean   : 691.3   Mean   :2296   Mean   : 362.8
#  3rd Qu.:353.7     3rd Qu.: 924.6   3rd Qu.:2698   3rd Qu.: 419.1
#  Max.   :579.0     Max.   :1201.1   Max.   :3308   Max.   :1115.2
#    population         Population        Income       Illiteracy
#  Min.   :  532668   Min.   :  365   Min.   :3098   Min.   :0.500
#  1st Qu.: 1791191   1st Qu.: 1080   1st Qu.:3993   1st Qu.:0.625
#  Median : 4340020   Median : 2838   Median :4519   Median :0.950
#  Mean   : 6067118   Mean   : 4246   Mean   :4436   Mean   :1.170
#  3rd Qu.: 6536963   3rd Qu.: 4968   3rd Qu.:4814   3rd Qu.:1.575
#  Max.   :36756666   Max.   :21198   Max.   :6315   Max.   :2.800
#     Life.Exp         Murder          HS.Grad          Frost
#  Min.   :67.96   Min.   : 1.400   Min.   :37.80   Min.   :  0.00
#  1st Qu.:70.12   1st Qu.: 4.350   1st Qu.:48.05   1st Qu.: 66.25
#  Median :70.67   Median : 6.850   Median :53.25   Median :114.50
#  Mean   :70.88   Mean   : 7.378   Mean   :53.11   Mean   :104.46
#  3rd Qu.:71.89   3rd Qu.:10.675   3rd Qu.:59.15   3rd Qu.:139.75
#  Max.   :73.60   Max.   :15.100   Max.   :67.30   Max.   :188.00
#       Area
#  Min.   :  1049
#  1st Qu.: 36985
#  Median : 54277
#  Mean   : 70736
#  3rd Qu.: 81162
#  Max.   :566432

# %%
head(fusion)
str(fusion)
# Out:
#   names      murder Forcible_rate Robbery aggravated_assult burglary
# 1 Alabama    8.2    34.3          141.4   247.8              953.8
# 2 Alaska     4.8    81.1           80.9   465.1              622.5
# 3 Arizona    7.5    33.8          144.4   327.4              948.4
# 4 Arkansas   6.7    42.9           91.1   386.8             1084.6
# 5 California 6.9    26.0          176.1   317.3              693.3
# 6 Colorado   3.7    43.4           84.6   264.7              744.8
#   larceny_theft motor_vehicle_theft population Population Income Illiteracy
# 1 2650.0        288.3                4627851    3615      3624   2.1
# 2 2599.1        391.0                 686293     365      6315   1.5
# 3 2965.2        924.4                6500180    2212      4530   1.8
# 4 2711.2        262.1                2855390    2110      3378   1.9
# 5 1916.5        712.8               36756666   21198      5114   1.1
# 6 2735.2        559.5                4861515    2541      4884   0.7
#   Life.Exp Murder HS.Grad Frost Area
# 1 69.05    15.1   41.3     20    50708
# 2 69.31    11.3   66.7    152   566432
# 3 70.55     7.8   58.1     15   113417
# 4 70.66    10.1   39.9     65    51945
# 5 71.71    10.3   62.6     20   156361
# 6 72.06     6.8   63.9    166   103766
# 'data.frame':	50 obs. of  17 variables:
#  $ names              : chr  "Alabama" "Alaska" "Arizona" "Arkansas" ...
#  $ murder             : num  8.2 4.8 7.5 6.7 6.9 3.7 2.9 4.4 5 6.2 ...
#  $ Forcible_rate      : num  34.3 81.1 33.8 42.9 26 43.4 20 44.7 37.1 23.6 ...
#  $ Robbery            : num  141.4 80.9 144.4 91.1 176.1 ...
#  $ aggravated_assult  : num  248 465 327 387 317 ...
#  $ burglary           : num  954 622 948 1085 693 ...
#  $ larceny_theft      : num  2650 2599 2965 2711 1916 ...
#  $ motor_vehicle_theft: num  288 391 924 262 713 ...
#  $ population         : int  4627851 686293 6500180 2855390 36756666 4861515 3501252 873092 18328340 9685744 ...
#  $ Population         : num  3615 365 2212 2110 21198 ...
#  $ Income             : num  3624 6315 4530 3378 5114 ...
#  $ Illiteracy         : num  2.1 1.5 1.8 1.9 1.1 0.7 1.1 0.9 1.3 2 ...
#  $ Life.Exp           : num  69 69.3 70.5 70.7 71.7 ...
#  $ Murder             : num  15.1 11.3 7.8 10.1 10.3 6.8 3.1 6.2 10.7 13.9 ...
#  $ HS.Grad            : num  41.3 66.7 58.1 39.9 62.6 63.9 56 54.6 52.6 40.6 ...
#  $ Frost              : num  20 152 15 65 20 166 139 103 11 60 ...
#  $ Area               : num  50708 566432 113417 51945 156361 ...

# %% [markdown]
# ### Task 1) Show the relationship between the following variables, using the most illustrative Bubble Chart possible.
#
# #### A)
#   1. HS.Grad
#   1. larceny_theft
#   1. Life.Exp
#   1. Income
#
# #### B) Then, provide your interpretation of the relationship your chart shows.

# %%
# 1.A) Add your code head(fusion)below this comment
# -------------------head(fusion)-------------

library(ggplot2)

pa <- ggplot(fusion, aes(x = Income, y = HS.Grad , size = Life.Exp, fill = larceny_theft)) +
        geom_point(shape = 21) +
        ggtitle("State Statistics") +
        labs(x = "Income", y = "Percent of High School Graduations") 
pa
# Out:
# plot without title

# %% [raw]
# # 1.B) Add your interpreation below
# #   this comment
# # --------------------------------
#
#
# There is a correlation between income, life Expectency and Hight School Graduation. Even though they each are correlated, never of the three is correlated with larceny theft.

# %% [markdown]
# ### Task 2) Show the relationship between the following variables, using the most illustrative Bubble Chart possible.
#
# #### A)
#   1. `population` ... note the lower case "p"
#   1. Area
#   1. Income
#   1. aggravated_assult
#
# #### B) Then, provide your interpretation of the relationship your chart shows.

# %%
# 2.A) Add your code below this comment
# --------------------------------


pa <- ggplot(fusion, aes(x = Income, y = aggravated_assult , size = population, fill = Area)) +
        geom_point(shape = 21) +
        ggtitle("State Statistics") +
        labs(x = "Income", y = "Aggravated Assult") 
pa
# Out:
# plot without title

# %% [raw]
# # 2.B) Add your interpreation below
# #   this comment
# # --------------------------------
#
#
#
# In general, there are more aggravated assults with the lower income, except for one outlier with extremely high income and assult rate. As expected we can also see that States with lower area in general have lower populations.

# %% [markdown]
# ### Task 3) Show the relationship between the following variables, using the most illustrative Bubble Chart possible.
#
# #### A)  Choose a new combination of variables.
#
# #### B) Then, provide your interpretation of the relationship your chart shows.

# %%
head(fusion)
# Out:
#   names      murder Forcible_rate Robbery aggravated_assult burglary
# 1 Alabama    8.2    34.3          141.4   247.8              953.8
# 2 Alaska     4.8    81.1           80.9   465.1              622.5
# 3 Arizona    7.5    33.8          144.4   327.4              948.4
# 4 Arkansas   6.7    42.9           91.1   386.8             1084.6
# 5 California 6.9    26.0          176.1   317.3              693.3
# 6 Colorado   3.7    43.4           84.6   264.7              744.8
#   larceny_theft motor_vehicle_theft population Population Income Illiteracy
# 1 2650.0        288.3                4627851    3615      3624   2.1
# 2 2599.1        391.0                 686293     365      6315   1.5
# 3 2965.2        924.4                6500180    2212      4530   1.8
# 4 2711.2        262.1                2855390    2110      3378   1.9
# 5 1916.5        712.8               36756666   21198      5114   1.1
# 6 2735.2        559.5                4861515    2541      4884   0.7
#   Life.Exp Murder HS.Grad Frost Area
# 1 69.05    15.1   41.3     20    50708
# 2 69.31    11.3   66.7    152   566432
# 3 70.55     7.8   58.1     15   113417
# 4 70.66    10.1   39.9     65    51945
# 5 71.71    10.3   62.6     20   156361
# 6 72.06     6.8   63.9    166   103766

# %%
# 3.A) Add your code below this comment
# --------------------------------


pa <- ggplot(fusion, aes(x = Income, y = Illiteracy , size = population, fill = Life.Exp)) +
        geom_point(shape = 21) +
        ggtitle("State Statistics") 
        labs(x = "Income", y = "Illiteracy") 
pa
# Out:
# $x
# [1] "Income"
#
# $y
# [1] "Illiteracy"
#
# attr(,"class")
# [1] "labels"
# plot without title

# %% [raw]
# # 3.B) Add your interpreation below
# #   this comment
# # --------------------------------
#
# The above shows the correlation that the higher the Illiteracy the lower the income. Also that life expectency grows with income.
