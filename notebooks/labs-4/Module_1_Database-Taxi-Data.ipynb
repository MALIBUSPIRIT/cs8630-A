# %% [markdown]
# ## Introduction to Database Computing with Big Data
#
# NYC taxi dataset is now available on dbase. Feel free to check out https://github.com/toddwschneider/nyc-taxi-data and the linked articles for more information. Taxi data available is as recent as June of this year.
#
# ### Postgres Database Environment
#
# For reference:
#
# host: dbase.dsa.missouri.edu
#
# user: dsa_ro_user
#
# pass: readonly
#
# database: nyc-taxi-data

# %%
# Lets explore the taxi data

# Connect to the taxi data

# Select a count from the taxi database

# Show descritive statistics (possibly show number of trips per day, etc.)

# %%
import psycopg2


try:
    connect_str = "dbname='nyc-taxi-data' user='dsa_ro_user' host='dbase.dsa.missouri.edu' " + \
                  "password='readonly'"
    # use our connection values to establish a connection
    conn = psycopg2.connect(connect_str)
    # create a psycopg2 cursor that can execute queries
    cursor = conn.cursor()
    # run a SELECT statement - no data in there, but we can try it
    cursor.execute("""SELECT * FROM cab_types""")
    rows = cursor.fetchall()
    print(rows)
except Exception as e:
    print("Uh oh, can't connect. Invalid dbname, user or password?")
    print(e)
# Out:
# [(1, 'yellow'), (2, 'green'), (3, 'uber')]

# %%
cursor.execute("""select * from fhv_bases;""")
rows = cursor.fetchall()
print(rows)
# Out:
# [('B00001', 'LONDON TOWNCARS INC', None, 'other'), ('B00008', 'T-D MAINTENANCE CORP', 'FOUR ONES CAR SERVICE', 'other'), ('B00009', 'T-D MAINTENANCE', 'FOUR ONES CAR SERVICE', 'other'), ('B00013', 'LOVE CORP CAR INC', None, 'other'), ('B00014', 'NY ONE CORP CAR INC', None, 'other'), ('B00021', 'MEXICANA HIGH CLASS INC.', 'CAPITAL CAR SERVICE', 'other'), ('B00029', 'COMMUNITY CAR SVC CORP', None, 'other'), ('B00030', 'TREMONT DISPATCHING CORP', None, 'other'), ('B00031', 'QUEENS VILLAGE INC.', None, 'other'), ('B00035', 'LOTUS RIDE INC', None, 'other'), ('B00037', 'TRANSP UNLIMITED C/S', None, 'other'), ('B00039', 'BERMUDA LIMOUSINE SERVICE INC.', None, 'other'), ('B00053', 'CHARGE AND RIDE INC', None, 'other'), ('B00054', '128 BLUE BIRD TRANSPORT INC.', 'LATCH CAR SERVICE', 'other'), ('B00078', 'R & R ROAD LIMO SVCE INC', None, 'other'), ('B00083', 'PAGE-A-RIDE INC', None, 'other'), ('B00084', 'AUTOMOTIVE SVC SYSTEM INC', None, 'other'), ('B00095', 'LIBERTY CAR SERVICE INC.', None, 'other'), ('B00106', 'HUMMINGBIRD CAR SVC', None, 'other'), ('B00112', 'HARBOR VIEW TRANS OF S I', 'HARBORVIEW CAR SERVICE', 'other'), ('B00131', 'NEW MEXICANA CAR SERVICE II INC.', 'AZTECA EXPRESS', 'other'), ('B00149', 'RAINBOW RAD DISP INC', None, 'other'), ('B00151 ', 'KINGSBAY CAR SERVICE INC', None, 'other'), ('B00160', 'JAFFA CAR & LIMO SVC INC', None, 'other'), ('B00170', 'EMUNAH CAR SERVICE INC', None, 'other'), ('B00171', 'SHAMROCK DISPATCH INC', "KELLY'S PRIVATE CAR SERVICE", 'other'), ('B00183', 'KEW GARDEN OPERATING CORP', None, 'other'), ('B00202', 'EXCELSIOR CAR & LIMO, INC.', None, 'other'), ('B00208', 'ERNEST SCHWARZ INC', None, 'other'), ('B00210', 'QUEENS DISPATCH SVC INC.', 'HOWARD', 'other'), ('B00220', 'BIG EAST MULTI GROUP CORP.', 'PREMIER CAR SERVICE', 'other'), ('B00221', 'PROFESSIONAL CAR SERVICE INC', None, 'other'), ('B00222', 'REYNO CAR SVC, INC.', None, 'other'), ('B00225', 'DELANCEY CAR SERVICE INC.', 'DELANCEY CAR SERVICE', 'other'), ('B00227', 'PARK WEST EXEC. SERVICES, INC.', 'TOWN CARS', 'other'), ('B00235', 'ARISTACAR & LIMOUSINE, LTD.', None, 'other'), ('B00236', 'LAST RADIO GROUP CORP.', None, 'other'), ('B00248', 'YELLOWSTONE TRANSPORTATION INC.', 'YES CAR SERVICE', 'other'), ('B00254', 'XYZ TWO WAY RADIO', None, 'other'), ('B00255', 'CAUTIOUS CARS INC.', None, 'other'), ('B00256', 'FAST OPERATING CORP', 'CARMEL C/L SVCE', 'other'), ('B00271', 'UTOG 2-WAY RADIO INC', 'UTOG CORPORATE CAR SERVICE', 'other'), ('B00272', 'BIG APPLE CAR INC', None, 'other'), ('B00277', 'ALL CITY CORP TRANS INC', None, 'other'), ('B00278', 'FAMILY CAR SERVICE', None, 'other'), ('B00280', 'FLEET RADIO DISPATCH CORP.', 'MINUTEMEN', 'other'), ('B00281', 'VEE CEE LIMOUSINE SERVICE, INC', 'NOSTRAND CAR SVCE', 'other'), ('B00290', 'ZPI CORPORATION', 'NATIONAL HIGH CLASS', 'other'), ('B00296', 'PRIME TIME TRANS. INC', None, 'other'), ('B00306', 'LOVE LIMOUSINE NYC LTD', None, 'other'), ('B00310', 'WATSON CAR SERVICE INC.', None, 'other'), ('B00318', 'APPLE RADIO CARS INC', None, 'other'), ('B00319', 'AVENTINE AUTO RENTAL INC', 'SAFEWAY CAR SVCE', 'other'), ('B00325', 'CONTINENTAL RADIO DISPATCH CORP.', None, 'other'), ('B00334', 'DO MAX CORP.', 'HIGH BRIDGE C/S', 'other'), ('B00337', 'KEW GARDENS ENTP INC', None, 'other'), ('B00345', "MARTIN'S BELLE HARBOR CAR SERVICE", None, 'other'), ('B00346', 'MERRICK C/S INC', None, 'other'), ('B00350', 'CHAMPION CAR & LIMO SVC. INC.', None, 'other'), ('B00369', 'BOULEVARD OPERATING INC.', None, 'other'), ('B00373', 'PARTICULAR PEOPLE CAR SERVICE INC.', None, 'other'), ('B00375', 'THE EXCELLENT C/S INC', None, 'other'), ('B00381', 'BELL RADIO INC', None, 'other'), ('B00385', 'DELINCE CAR LIVERY SERVICE CORP.', 'WHITE TOP CAR SERVICE', 'other'), ('B00387', 'FORTUNE LIMOUSINES INC', None, 'other'), ('B00401', 'TREMONT DISPATCHING CORP', None, 'other'), ('B00411', 'FONE-A-CAR INC', None, 'other'), ('B00412', 'NYC 2 WAY INTERNATIONAL LTD', 'NYC TWO WAY INC.', 'other'), ('B00419', 'KOOP DISPATCHING INC.', N ...
